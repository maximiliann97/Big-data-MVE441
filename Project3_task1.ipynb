# %% [markdown]
# # Task 1
# Investigate at least 4 different clustering methods on the "CancerData.txt" data set.
#
# Consider different dimension and feature selection techniques. Remember - it's a clustering task so you cannot select based on the class label!!!
#
# Questions to focus on:
#
# - Do the detected clusters overlap with the classes? Do some classes stand out?
#
# - Do cluster selection methods (try at least 2) propose 3 clusters or more/fewer?
#
# - How sensitive are any of the results above to how many features or reduced dimensions you use? and does this depend on which clustering method you use?
#
# - How stable are the clustering results (investigate via resampling, consensus clustering etc)?

# %% [markdown]
# ## Data preparation

# %%
import numpy as np

labels = list()

with open('Cancerdata.txt') as f:
    lines = f.readlines()
    for i, line in enumerate(lines):
        if i == 0:
            continue
        line = line.split('\t')
        line = [item.rstrip() for item in line]
        line[0] = float(line[0].strip('"'))
        line[1:] = [float(x) for x in line[1:]]
        line = np.asarray(line)
        
        # Append labels
        labels.append(int(line[1]))
        
        # Create the data np.array with first observation
        # Vstack the rest of the observations to the newly created data matrix
        observation = line[2:]
        if i == 1:
            data = observation
        else:
            data = np.vstack((data, observation))
        
labels = np.asarray(labels)

print(np.shape(labels))
print(np.shape(data))
# Out:
# (82,)
# (82, 2999)

# %% [markdown]
# ### Plot functions

# %%
def plot_true_vs_predict_2d(true_labels, predicted_labels, pca_component1=None, pca_component2=None):
    pca_component1 = 0 if pca_component1 is None else pca_component1
    pca_component2 = 1 if pca_component2 is None else pca_component2

    colors = ['red', '#7FFF00', 'blue']
    plt.figure(3)

    for i in u_labels:
        plt.scatter(principal_components_pca[predicted_labels == i , pca_component1] , principal_components_pca[predicted_labels == i , pca_component2] , label = i, color=colors[i])
        plt.scatter(principal_components_pca[true_labels == i , pca_component1] , principal_components_pca[true_labels == i , pca_component2] , label = i, marker="x", color=colors[i], zorder=5)

    plt.title('Plot of the real-label and kMean-label')
    plt.xlabel('Principal component ' + str(pca_component1+1))
    plt.ylabel('Principal component ' + str(pca_component2+1))

# %%
def plot_true_vs_predict_3d(true_labels, predicted_labels, pca_component1=None, pca_component2=None, pca_component3 = None):
    pca_component1 = 0 if pca_component1 is None else pca_component1
    pca_component2 = 1 if pca_component2 is None else pca_component2
    pca_component3 = 2 if pca_component3 is None else pca_component3

    colors = ['red', '#7FFF00', 'blue']
    fig = plt.figure()
    ax = fig.add_subplot(111, projection ='3d')


    for i in u_labels:
        plt.scatter(principal_components_pca[predicted_labels == i , pca_component1] , principal_components_pca[predicted_labels == i , pca_component2], principal_components_pca[predicted_labels == i , pca_component3] , label = i, color=colors[i])
        plt.scatter(principal_components_pca[true_labels == i , pca_component1] , principal_components_pca[true_labels == i , pca_component2], principal_components_pca[true_labels == i , pca_component3], label = i, marker="x", color=colors[i], zorder=5)

    plt.title('Plot of the real-label and kMean-label')
    plt.xlabel('Principal component ' + str(pca_component1+1))
    plt.ylabel('Principal component ' + str(pca_component2+1))

# %%
import math
import pandas as pd
from matplotlib.patches import Rectangle

def plot_difference_real(true_labels, predicted_labels, pca_component1=None, pca_component2=None):
    pca_component1 = 0 if pca_component1 is None else pca_component1
    pca_component2 = 1 if pca_component2 is None else pca_component2

    fig, ax1 = plt.subplots(1)
    
    #Vi vill ha den kvadratisk för att enklare kunna se clusters
    fig.set_size_inches(7, 7)
    
    custom_xlim = (-30, 30)
    custom_ylim = (-30, 30)
    plt.setp(ax, xlim=custom_xlim, ylim=custom_ylim)
    
    colors_fill = ['#C7054C', '#1E88E5', '#FFC107', '#06A086', '#D0C5C5', '#60A499']
    colors_edge = ['#8A072B', '#0068C3', '#BF9001', '#005446', '#9C9C9C', '#335A54']
    
    markers = ['o', 's', 'v', 'D', "X", ">"]
    
    #Plottar alla clusters med Färg = true, marker = pred
    
    for i in range(len(true_labels)):
        component = [principal_components_pca[i , pca_component1], 
                             principal_components_pca[i, pca_component2]]
        ax1.scatter(component[0], component[1], color=colors_fill[true_labels[i]], 
                    marker = markers[predicted_labels[i]], edgecolor = colors_edge[true_labels[i]])
    
    
        ax1.set_xlabel('Principal component ' + str(pca_component1))
        ax1.set_ylabel('Principal component ' + str(pca_component2))
        ax1.set_title('Real and predicted clusters')
        
        extra1 = Rectangle((0, 0), 1, 1, fc="w", fill=False, edgecolor='none', linewidth=0)
        extra2 = Rectangle((0, 0), 1, 1, fc="w", fill=False, edgecolor='none', linewidth=0)
        
        ax1.legend([extra1, extra2], ("Shape = Pred.", "Colour = True"))

# %%
def get_wrong_info(true_labels, predicted_labels, nr_of_clusters, pca_component1=None, pca_component2=None):
    pca_component1 = 0 if pca_component1 is None else pca_component1
    pca_component2 = 1 if pca_component2 is None else pca_component2
    
    nr_of_wrong = np.zeros(nr_of_clusters)
    nr_of_missed = np.zeros(nr_of_clusters)
    
    #Vi loopar igenom alla tre clusters.
    for pred in range(nr_of_clusters):
        max_common = 0
        max_cluster = 0
        
        #Väljer ut det pred. clustret vi tittar på och vill finna info om
        predicted_cluster = np.array([principal_components_pca[predicted_labels == pred , pca_component1], 
                             principal_components_pca[predicted_labels == pred , pca_component2]])

        
        #Loopar igenom "orginal-clustern"
        for j in range(3):
            common = 0   
            true_cluster = np.array([principal_components_pca[true_labels == j , pca_component1], 
                            principal_components_pca[true_labels == j , pca_component2]])
            
            #Ser hur många som överrensstämmer i de två clusterna
            for i in range(predicted_cluster.shape[1]):
                for k in range(true_cluster.shape[1]):
                    if np.array_equal(true_cluster[0:2, k], predicted_cluster[0:2, i]):
                        common += 1

            #Tar ut det "orginal-clustret" som stämmer mest överrens med predicted
            if common > max_common:
                max_common = common
                max_cluster = j
        
        #Tar ut det "bästa orginal-clustret"
        cluster = np.array([principal_components_pca[true_labels == max_cluster , pca_component1], 
                            principal_components_pca[true_labels == max_cluster , pca_component2]])
        

        
        #Tar ut hur mycket som är "fel" och "missat" av det predikterade
        wrong = []
        for i in range(predicted_cluster.shape[1]):
            col_pred = predicted_cluster[0:2, i]
            not_in = 0
            
            #Checkar mot alla i den andta
            for k in range(cluster.shape[1]):
                col_true = cluster[0:2, k]
                if np.array_equal(col_pred, col_true):
                    not_in += 1

            if not_in < 1:
                wrong.append(col_pred)
             
        missed = []
        for i in range(cluster.shape[1]):
            col_pred = cluster[0:2, i]
            not_in = 0

            for k in range(predicted_cluster.shape[1]):
                col_true = predicted_cluster[0:2, k]
                if np.array_equal(col_pred, col_true):
                    not_in += 1

            if not_in < 1:
                missed.append(col_pred)

        nr_of_missed[pred] = len(missed)
        nr_of_wrong[pred] = len(wrong)
        
    #Presenterar infon om missade och fel-clustrade
    all_info = np.stack((nr_of_wrong, nr_of_missed), axis = 1)
    wrong_info = pd.DataFrame(all_info, columns = ["Number of wrong in each cluster", "Number of missed in each cluster"])#['Nr. of wrong: cluster 1','Nr. of wrong: cluster 2','Nr. of wrong: cluster 3'])

    return wrong_info

# %%
def get_average_wrong_info_kmeans(reduced_data, nr_of_itt, nr_clusters, score):

    average_wrong_info = np.zeros([nr_clusters, 2])

    for i in range(nr_of_itt):
        k, pred_kmeans, a = kmeans_clustering_score(reduced_data,  nr_clusters, score)
        wrong_info = get_wrong_info(labels, pred_kmeans, nr_clusters)

        average_wrong_info[:, 0] += wrong_info.get("Number of wrong in each cluster")
        average_wrong_info[:, 1] += wrong_info.get("Number of missed in each cluster")


    average_wrong_info[:, 0] = average_wrong_info[:, 0]/nr_of_itt
    average_wrong_info[:, 1] = average_wrong_info[:, 1]/nr_of_itt

    wrong_info = pd.DataFrame(average_wrong_info, columns = ["Number of wrong in each cluster", "Number of missed in each cluster"])
    
    return wrong_info

# %%
def get_average_wrong_info_sc(reduced_data, nr_of_itt, nr_clusters, score):

    average_wrong_info = np.zeros([nr_clusters, 2])

    for i in range(nr_of_itt):
        k, pred_sc, a = spectral_clustering_score(reduced_data, nr_clusters, score)
        wrong_info = get_wrong_info(labels, pred_sc, nr_clusters)

        average_wrong_info[:, 0] += wrong_info.get("Number of wrong in each cluster")
        average_wrong_info[:, 1] += wrong_info.get("Number of missed in each cluster")


    average_wrong_info[:, 0] = average_wrong_info[:, 0]/nr_of_itt
    average_wrong_info[:, 1] = average_wrong_info[:, 1]/nr_of_itt

    wrong_info = pd.DataFrame(average_wrong_info, columns = ["Number of wrong in each cluster", "Number of missed in each cluster"])
    
    return wrong_info

# %%
nr_of_clusters = 3
reduced_data = pca(data, 10)
nr_of_itt = 100

wrong_info = get_average_wrong_info_kmeans(reduced_data, nr_of_itt, nr_of_clusters, 'kmean')
print(wrong_info)
k, pred_kmeans, a = kmeans_clustering_score(reduced_data, nr_of_clusters, 'kmean')
plot_difference_real(labels, pred_kmeans)
# Out:
#    Number of wrong in each cluster  Number of missed in each cluster
# 0                             6.76                             10.04
# 1                             8.94                              7.89
# 2                             7.33                              8.31

# %%
nr_of_clusters = 3
reduced_data = pca(data, 10)
nr_of_itt = 100

wrong_info = get_average_wrong_info_sc(reduced_data, nr_of_itt, nr_of_clusters, 'kmean')
print(wrong_info)

k, pred_sc = spectral_clustering_score(reduced_data, nr_of_clusters, 'kmean')
plot_difference_real(labels, pred_sc)
# Out:
# [[-3.52278475e+00  2.29406540e+01 -6.20675163e+00  1.80016953e+01
#   -1.13358075e+01 -7.18146702e-02 -3.02670021e+00 -6.81629582e+00
#   -1.71607118e+00  1.71833031e+00]
#  [ 1.71432509e+01 -9.42704702e+00  1.15398453e+01 -4.22020629e+00
#   -1.90324353e+01 -1.18798944e+01 -2.10501035e-01 -1.87364428e+01
#    2.46145994e-01  7.23644832e-01]
#  [ 9.54709344e+00  1.57360299e+01 -4.64257031e+00  1.50923346e+01
#    9.49363892e+00  2.99202294e+00 -3.78951088e+00 -7.06312574e-01
#   -2.28107255e+00  9.01261958e+00]
#  [ 9.80261664e+00  3.78053251e+00  8.60404527e+00 -2.06116791e-01
#    2.67065797e+01 -9.13568185e+00 -9.82674654e+00  1.76920844e+01
#    2.05786057e+01  1.75326885e+01]
#  [-5.86164945e+00 -3.25108515e+01  3.59494330e+00  3.45043102e+01
#   -2.19272235e+00  7.50689535e+00  1.70258698e+01  9.71178732e-03
#    3.92649037e+00 -6.00328289e+00]
#  [-3.70147782e+01 -1.34263138e+01  1.85296683e+01 -4.79838720e-02
#    1.81902832e-02 -1.20394117e+01  7.69912651e+00  1.42986920e+01
#   -5.59636748e+00 -2.99361838e+00]
#  [-2.12601597e+01 -2.18375321e+01 -2.25419157e+01 -5.44154817e+00
#   -9.77568206e+00  6.05689784e+00 -2.00582459e+01  5.30034123e+00
#    1.06959270e+00 -2.41818236e-01]
#  [ 7.29818335e+00 -6.81642625e+00 -1.95711829e+01 -8.19220800e+00
#    1.08896337e+01 -2.19853066e+00  1.26727163e+01 -7.75879784e+00
#   -1.43405873e+01 -9.30983067e-01]
#  [-2.77026043e+01  1.85816800e+01  2.11730468e+01 -9.00927128e+00
#   -3.27851077e-02 -3.84569227e+00  1.16534361e+01  9.64921285e+00
#    1.51563468e+01 -3.95246245e+00]
#  [-2.44418840e+00 -1.69289859e+01  1.53031595e+01  1.81075751e+01
#   -3.37285900e+00 -7.20177770e-01 -3.81133024e+00  1.82441914e+01
#   -3.50464288e+00  9.86502715e+00]
#  [ 2.55583109e+00  8.14992910e+00 -1.30952803e+01  5.57234246e+00
#   -7.87656345e+00 -4.32966240e+00  1.31341938e+01  3.57685787e+00
#   -3.54341904e+00  2.03218654e+00]
#  [-1.83486675e+01 -4.24434607e+00 -3.12462157e+00  1.42830015e+01
#   -3.64531008e+00 -8.79956481e-01 -5.31334752e+00 -6.85920641e+00
#    6.84165764e+00 -6.79192173e+00]
#  [ 1.04779182e+01  8.29135399e+00  1.28677398e+01 -6.44475034e+00
#    5.01309116e+00 -1.93936747e+00  5.59553458e+00  1.37428425e+00
#   -4.04023446e+00 -2.36569151e+00]
#  [-6.50216109e+00  2.32961265e+01 -4.93309943e+00  1.82867090e+01
#   -1.31936444e+01  7.88527534e-01 -2.99872069e+00 -9.44155508e+00
#   -1.69081893e+00  2.95347860e+00]
#  [ 7.84150410e+00  1.78735852e+00 -2.35828266e+01 -8.32137580e-01
#    7.09994706e+00 -1.05703219e+01  1.16080567e+01 -2.43835306e+00
#    1.73580086e+01  1.77829490e+01]
#  [-1.99770226e+01 -2.27506539e+01 -1.29671121e+01  7.05700912e+00
#    7.77433939e+00 -9.33331608e+00 -1.00447210e+00 -7.67032381e-01
#   -2.84471733e+00 -1.63145104e+01]
#  [-1.61292814e+01  9.11186864e+00  2.76677762e+01 -8.67367071e+00
#   -6.99722190e+00 -5.59968560e+00  1.20937975e+00  9.03198268e+00
#   -9.54314314e+00  3.05256008e+00]
#  [ 3.13367910e+01 -9.42656386e+00  9.21344753e-01 -1.32438232e+01
#    8.79997965e+00 -1.61906410e+01 -1.38516069e+00 -4.78548827e+00
#   -9.82817222e-01 -5.95592022e+00]
#  [-3.37221619e+00 -8.87901237e-01  1.90646980e+01  9.59978468e+00
#   -1.20265821e+01 -8.59203376e+00 -2.73062612e+00  8.76854764e+00
#   -2.39851380e+00 -3.66059088e+00]
#  [-1.38834230e+01 -2.32987348e+01  1.09061907e+01  1.80770938e+01
#    2.20268649e+01  6.66143652e+00  1.42003993e+01 -9.28319225e+00
#   -8.92807616e+00  6.05966949e+00]
#  [-2.44394897e+01 -1.33703792e+01 -1.48449384e+01 -1.23324683e+00
#   -7.30354097e-01  5.70495470e+00 -1.09103112e+01 -5.13783055e+00
#    2.67116583e+00 -4.48940728e+00]
#  [ 1.78549926e+01 -8.39929813e+00  1.16218821e+01 -3.46962917e+00
#    4.70038811e-01  5.84593917e+00 -1.52285204e-01  9.63597221e+00
#   -8.30274244e+00  4.42731868e+00]
#  [ 2.15576601e+01  1.02681137e+01  1.12395926e+01 -2.64445363e+00
#    1.74627127e+01  1.91770649e+00 -1.37870225e+01 -8.17232642e+00
#   -1.10654599e+00 -1.08491143e+01]
#  [ 1.00325742e+01 -1.42199308e+01 -2.18740181e+01 -1.08599542e+01
#    1.20531774e+01 -1.65478309e+00  1.49147813e+01 -1.05504099e+01
#   -1.54618366e+01  1.36565587e-01]
#  [-2.53403143e+01  1.92476027e+01  1.24755161e+01 -1.85968887e+01
#    2.48901703e+00  6.82757758e+00 -1.08701531e+01 -5.51120764e+00
#    2.70145161e+00  1.49917644e+00]
#  [-2.02703932e+01 -5.01565384e+00 -6.32896384e+00 -3.09153845e+00
#    6.10535641e+00 -1.08608285e+01 -3.88744844e-01 -1.14337162e+01
#    3.53909810e+00  6.65678406e-02]
#  [-5.05478456e+00  3.19170110e+01 -6.17386993e+00  8.30062681e+00
#    5.69552629e+00 -4.21353570e+00 -7.54282851e-01  6.91722989e+00
#   -7.19497264e+00 -4.51432930e+00]
#  [ 2.62368292e+01 -1.50976631e+01 -1.16197992e+01  1.09657585e+01
#   -1.75704684e+01  1.30305997e+01 -1.18711316e+00  9.50997499e+00
#   -7.14140556e+00  6.67510347e+00]
#  [-2.15604934e+01 -3.88426392e+00 -1.86767850e+01 -2.05974578e+01
#   -5.15674055e+00  1.09216306e+01 -2.13938940e+01  1.33565686e+01
#   -7.97978869e+00  9.57641627e+00]
#  [ 3.54309171e+01 -9.56447306e-01  4.74603820e+00  4.01748903e+00
#    1.23467509e+01 -5.75433097e+00 -1.25113516e+01 -1.61730760e+00
#    3.23829037e+00 -1.01600419e+01]
#  [ 3.40708618e+01 -1.59858116e-01  1.15312989e+01 -1.17512334e+01
#    9.52207614e+00 -7.38249069e+00 -7.45200152e-01 -6.79070008e-02
#   -4.69296073e+00 -9.80785093e-01]
#  [ 1.31680572e+00 -4.31830726e+00 -8.87544223e+00 -1.73211804e+01
#   -6.81654734e-01 -9.85299789e+00  1.59865163e+01 -9.94627533e+00
#   -8.11460718e+00 -1.94249018e+00]
#  [ 3.65621986e+01 -2.37544733e+00  1.34452100e+01  8.35546759e+00
#   -4.72095805e+00  5.07281074e+00 -9.51985407e+00 -7.83959869e+00
#   -7.98518994e-01 -5.15217477e+00]
#  [ 3.87168800e+01  7.93788859e-01  7.39708828e+00  1.41341615e+00
#    6.10064164e+00 -3.98707939e+00 -1.19909907e+01 -9.65375147e+00
#    1.29644556e+00 -5.90463671e+00]
#  [ 1.27493925e+01  1.36717304e+01 -4.20235920e+00  1.60957287e+01
#    1.36249329e+01  1.82844100e+00 -4.84541522e+00  4.39623079e-01
#   -2.70771583e+00  9.46021551e+00]
#  [ 2.01850397e+01 -1.09958544e+01  1.22199448e+01 -2.68286110e+00
#   -1.80353220e+01 -3.01388275e+00  5.41717313e-01 -8.62338857e+00
#    1.48297927e+01 -4.28023085e+00]
#  [-1.69217580e-01  8.35144792e-01  8.45286804e+00  1.34128153e+00
#   -4.48813896e+00 -1.73927694e+00  7.91508646e+00  1.98101839e+01
#   -2.19951870e+00 -1.15451268e+01]
#  [ 3.53703536e+01 -1.71169916e+00 -2.57552777e+00 -1.22924855e+01
#    6.57567036e+00  6.01781831e+01  2.33522962e+01  1.45911279e+01
#    1.15610615e+01 -1.55289002e+01]
#  [ 6.36757011e+00 -3.46603654e-01 -7.36120551e+00 -2.42677524e+01
#    5.77797208e+00 -5.39198810e+00  1.54033459e+01 -1.41366634e+00
#   -1.02752097e+01 -3.89494497e+00]
#  [-4.83134439e+00  3.26503894e+01 -9.44445875e+00  6.02896773e+00
#    3.44948855e+00 -4.24384468e+00 -2.90099895e-02  7.62564434e+00
#   -7.97528291e+00 -6.59099074e+00]
#  [ 1.10209188e+01 -2.85735616e+01 -2.10724710e+01  2.25204622e+00
#   -8.97028941e+00  1.29833619e+01 -1.25164153e+01  6.73856922e+00
#   -2.24802841e+00  4.46284419e+00]
#  [ 7.79511225e+00 -1.06592307e+01 -7.88545509e+00 -2.30397381e+01
#   -1.24955365e+01 -3.43857641e+00 -6.92634540e+00  8.92809669e+00
#    5.28323386e+00  1.94599509e+01]
#  [-2.33068592e+00  1.45542136e+01  1.25674325e+01  2.23659696e+00
#    3.22822730e+00  3.95595729e+00 -1.53752875e+01 -1.22099617e+01
#    1.02931297e+01 -8.59839573e+00]
#  [ 6.23567233e+00 -1.59240745e+01  1.40173077e+01  1.90600607e+01
#    4.07377484e+00 -5.31472040e+00 -3.31782541e+00  1.80581082e+01
#   -8.33085041e+00 -4.78515329e+00]
#  [-1.66142041e+01  7.27843659e+00 -4.29046756e+00 -2.56292833e+01
#   -6.15579022e+00  9.58478316e+00  4.14918876e+00 -8.01788772e+00
#   -1.29914276e+00 -1.27605440e+01]
#  [-2.98579999e+01  1.95042672e+01  2.09032650e+01 -1.12727777e+01
#   -2.04663864e+00  3.02443326e+00  7.75704394e+00  1.25596126e+01
#    2.44792403e+01 -5.80798498e+00]
#  [ 5.44332555e+00 -5.16516333e+00  6.18839873e+00  1.73704923e+00
#   -2.33743423e+01  8.92331143e-01  5.76541437e+00 -1.24096159e+01
#    3.95799254e+00 -2.48458591e+00]
#  [ 1.34921447e+01  2.05715015e+01 -1.53114397e+01  1.40713250e+01
#   -8.89153364e-01 -3.96106692e+00 -2.70900263e+00  7.62550527e+00
#   -2.76675982e+00 -5.14634593e+00]
#  [-1.96120712e+01 -7.52415701e+00 -1.69092613e+01 -1.25600465e+01
#    1.51451555e+01  2.90978326e+00 -9.71087131e+00 -5.08674836e+00
#   -1.05951961e+01 -8.36779180e+00]
#  [-3.47545188e+01  8.71615999e-01  2.12874659e+01 -5.48825808e-02
#    3.30784448e+01  1.26008595e+01  1.50814417e+00 -1.84162270e+01
#   -1.73788463e+01  2.26235044e+01]
#  [ 1.23640584e+00  1.20975514e+01 -1.15460913e+01  8.47215952e+00
#   -1.13935765e+01 -4.80169993e+00  1.28199724e+01  6.06990511e+00
#   -1.44016889e+00  2.36670788e+00]
#  [ 1.11278204e+01  1.92712005e+01 -2.28453069e+01  3.55164092e+00
#   -3.12540093e+00  1.50070310e+00 -4.58531491e-01  2.97179489e+00
#   -6.97693946e+00 -3.28354320e+00]
#  [-1.27760475e+01 -1.48240781e+01  1.42943995e+01  1.66316286e+01
#   -5.52741816e+00 -2.85640966e+00 -3.66952323e+00  1.16652319e+01
#   -5.16238067e+00  7.16070155e-02]
#  [ 3.30955308e+01  5.47901818e-01  1.10845836e+01 -7.53431056e+00
#    1.03373098e+01  9.35704482e-01 -6.64196473e+00  1.80937797e+00
#   -1.27243270e+00  2.06284918e+00]
#  [-5.21029515e+00 -1.02810831e+01 -4.64209075e+00  2.95933398e+00
#   -2.03889281e+01  5.11571999e+00  2.79281881e+00 -1.55072682e+01
#    1.13826935e+01 -9.73026651e-01]
#  [-3.98086532e+01 -1.09997041e+01 -1.30766947e+01 -1.91975248e+01
#    1.36944363e+00 -3.10820073e+00 -1.37318806e+01  9.72601731e+00
#    2.22217542e+00 -7.32518326e+00]
#  [-1.06614318e+01 -2.80589546e+01 -1.74850231e+01  1.06049558e+01
#    7.96160206e+00 -3.86687839e+00  8.22324140e-01 -1.98706876e+00
#    1.42286082e+01 -8.46083200e+00]
#  [ 1.10943475e+01 -2.29223756e+00  1.00394871e+01 -1.20659798e+01
#   -4.04139506e+00  3.97099628e+00 -9.40673803e-01  2.78330502e+00
#   -6.92074121e+00  8.20374515e+00]
#  [-1.67450835e+01  8.75622945e+00  1.92925782e+01  5.76196874e+00
#    8.07320566e+00  2.37552183e+01  1.76769721e+00 -1.55798425e+01
#    6.72163811e+00  9.83689545e+00]
#  [-2.12968315e+01 -6.05588083e+00  4.72892952e+00 -9.04308830e+00
#    5.27617565e+00 -1.14414096e+01  9.72987949e+00  1.15779908e+01
#    9.17264488e+00  7.36330503e-01]
#  [-1.46709773e+01 -1.95178976e+01  9.11021546e+00  1.69137045e+01
#    1.85238754e+01 -3.49648379e+00  5.96381557e+00  1.67083955e+00
#    9.22535490e-01 -4.62420980e+00]
#  [-2.07310196e+01 -1.79203139e+01 -1.42926266e+01  5.10490913e+00
#    2.98872291e+00 -1.37934733e+00 -8.78815104e+00 -7.55248214e+00
#    5.84022161e+00 -1.15097948e+01]
#  [ 1.38640343e+01 -1.43778193e+01  9.33650663e+00 -9.39319639e+00
#   -2.29682041e+01  8.46941740e+00 -1.26093563e+01  4.19614951e+00
#   -1.02323377e+01  1.51778485e+01]
#  [-2.40534837e+01 -3.22310305e+00  7.75484420e-01  2.14321890e+00
#    1.14186728e+01  6.15889293e+00 -3.70091238e+00 -5.39683690e+00
#   -5.06381635e+00  5.32139087e-01]
#  [-8.59926789e+00  2.74337274e+01 -7.13709992e+00  9.40643471e+00
#   -1.39170267e+01  9.58565392e+00  2.19394705e+00 -7.19994794e+00
#    1.36572706e-01  6.47624266e+00]
#  [ 2.19857486e+01 -1.00484174e+00  1.30800316e+01  1.01927882e+00
#   -2.35288925e+01 -2.70134020e+00  1.81725176e+00 -7.81865859e+00
#   -2.76111653e+00 -2.58855000e+00]
#  [ 1.42389936e+01  1.85609195e+01 -2.60062846e+01  9.51334791e-01
#   -1.34865208e+00  1.62638114e+00 -1.02628094e-02  5.16238606e+00
#   -7.90978426e+00 -4.38419410e+00]
#  [ 4.16340903e+01 -1.02292368e+01  4.65543065e+00  8.36554222e-01
#    1.29240337e+01 -8.02984068e+00 -6.93097093e+00 -5.66120218e+00
#    1.28482819e+01 -6.24673550e+00]
#  [-8.19669815e+00  3.51367664e+01 -6.52178359e+00  6.92502061e+00
#    4.29621925e+00 -5.27976689e+00 -3.23183154e-02  8.06033697e+00
#   -7.98684149e+00 -6.98042544e+00]
#  [ 7.84150410e+00  1.78735852e+00 -2.35828266e+01 -8.32137580e-01
#    7.09994706e+00 -1.05703219e+01  1.16080567e+01 -2.43835306e+00
#    1.73580086e+01  1.77829490e+01]
#  [-1.43187504e+01  1.45450254e+01  1.45637238e+01 -3.96362078e-01
#    3.40389394e+00  8.50467973e-01 -1.53575338e+01 -1.22032339e+01
#    7.93872652e+00 -9.24873399e+00]
#  [ 4.26900520e+00 -1.65277619e+00  1.59748827e+01 -9.02246164e+00
#   -2.63189656e+00 -5.85954352e+00  1.55024470e+01  2.80173366e-01
#   -7.02886181e+00  3.11319261e-01]
#  [-1.43603187e+01 -1.39219065e+01 -1.13174295e+00  6.89804291e+00
#   -4.64684290e+00  5.39073774e+00  1.18538263e+01 -1.57447723e+00
#    1.73165696e+00 -2.11837023e+00]
#  [-5.69398077e+00 -4.06710272e+00 -5.58264968e-01 -1.39927740e+01
#   -1.35600542e+01 -1.88332340e+00  5.38202899e-01 -1.68202555e+00
#    6.52447457e+00  6.72581910e+00]
#  [-6.13315209e+00  2.35867720e+01 -9.60395893e+00  7.87064887e+00
#   -1.07644806e+01  6.56225754e+00  3.60606350e+00 -6.48570871e+00
#    2.71978810e+00  8.17224861e+00]
#  [-1.71467086e+01  9.84243113e+00  1.31349181e+01 -1.84146461e+01
#   -1.47401545e+01 -8.35917272e+00  1.21563299e+01 -4.49429333e+00
#   -8.32050889e+00 -8.95701542e+00]
#  [-2.85025196e+01  4.96655903e+00  7.97646519e+00  3.83224021e+00
#    1.37995430e+00  1.48062084e+01 -7.35373977e+00 -3.15470361e+00
#   -8.73923138e-01  1.07983185e+01]
#  [ 6.85073936e+00  3.33388746e+00 -2.17773163e+01  5.63506985e-01
#    4.32591852e+00 -9.70502863e+00  1.17898441e+01 -1.16211434e+00
#    1.45382820e+01  1.54705128e+01]
#  [ 4.21816179e+01 -4.43103939e-01  8.52728046e+00 -1.89244853e+01
#    1.39936361e+01  2.07131224e+00 -1.62669701e+00  8.31567263e+00
#    3.54922061e+00  3.26122035e+00]
#  [ 1.33603479e+01  2.09263101e+01 -1.34241141e+01  1.63866174e+01
#   -8.08065354e-01 -4.94708716e+00 -3.18525084e+00  8.06017337e+00
#   -1.85916727e+00 -5.28084331e+00]
#  [ 5.68504982e+00 -1.04208261e+01  2.16280717e+01  4.14810693e+00
#   -1.72970322e+01 -1.06162464e+01  8.55844101e-02 -6.91396911e+00
#   -7.67179268e+00  1.10141999e+01]
#  [-1.51480001e+01 -5.08817335e+00 -1.47257072e+01 -8.94488369e+00
#   -2.90881815e+00 -5.04711276e+00 -8.30580367e+00  4.42121157e+00
#    2.59794509e+00 -3.14553825e+00]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 7
#       3 nr_of_itt = 100
#       5 print(reduced_data)
# ----> 7 wrong_info = get_average_wrong_info_sc(reduced_data, nr_of_itt, nr_of_clusters, 'kmean')
#       8 print(wrong_info)
#      10 k, pred_sc = spectral_clustering_score(reduced_data, nr_of_clusters, 'kmean')
#
# Cell In[36], line 6, in get_average_wrong_info_sc(reduced_data, nr_of_itt, nr_clusters, score)
#       3 average_wrong_info = np.zeros([nr_clusters, 2])
#       5 for i in range(nr_of_itt):
# ----> 6     k, pred_sc, a = spectral_clustering_score(reduced_data, nr_clusters, score)
#       7     wrong_info = get_wrong_info(labels, pred_sc, nr_clusters)
#       9     average_wrong_info[:, 0] += wrong_info.get("Number of wrong in each cluster")
#
# Cell In[23], line 40, in spectral_clustering_score(reduced_data, nr_clusters, score)
#      37 def spectral_clustering_score(reduced_data, nr_clusters, score):
#      38     sc = SpectralClustering(n_clusters=nr_clusters, eigen_solver='lobpcg', n_init=10, gamma=1.0, affinity='precomputed_nearest_neighbors',
#      39                         n_neighbors=10, assign_labels='kmeans')
# ---> 40     pred = sc.fit_predict(reduced_data)
#      41     if score == 'silh':
#      42         score = silhouette_score(reduced_data, pred, metric='euclidean')
#
# File ~\OneDrive\Skrivbord\Big Data\venvBigData\lib\site-packages\sklearn\cluster\_spectral.py:785, in SpectralClustering.fit_predict(self, X, y)
#     763 def fit_predict(self, X, y=None):
#     764     """Perform spectral clustering on `X` and return cluster labels.
#     765
#     766     Parameters
#    (...)
#     783         Cluster labels.
#     784     """
# --> 785     return super().fit_predict(X, y)
#
# File ~\OneDrive\Skrivbord\Big Data\venvBigData\lib\site-packages\sklearn\base.py:753, in ClusterMixin.fit_predict(self, X, y)
#     735 """
#     736 Perform clustering on `X` and returns cluster labels.
#     737
#    (...)
#     749     Cluster labels.
#     750 """
#     751 # non-optimized default implementation; override when a better
#     752 # method is possible for a given clustering algorithm
# --> 753 self.fit(X)
#     754 return self.labels_
#
# File ~\OneDrive\Skrivbord\Big Data\venvBigData\lib\site-packages\sklearn\cluster\_spectral.py:732, in SpectralClustering.fit(self, X, y)
#     728     self.affinity_matrix_ = 0.5 * (connectivity + connectivity.T)
#     729 elif self.affinity == "precomputed_nearest_neighbors":
#     730     estimator = NearestNeighbors(
#     731         n_neighbors=self.n_neighbors, n_jobs=self.n_jobs, metric="precomputed"
# --> 732     ).fit(X)
#     733     connectivity = estimator.kneighbors_graph(X=X, mode="connectivity")
#     734     self.affinity_matrix_ = 0.5 * (connectivity + connectivity.T)
#
# File ~\OneDrive\Skrivbord\Big Data\venvBigData\lib\site-packages\sklearn\neighbors\_unsupervised.py:176, in NearestNeighbors.fit(self, X, y)
#     159 """Fit the nearest neighbors estimator from the training dataset.
#     160
#     161 Parameters
#    (...)
#     173     The fitted nearest neighbors estimator.
#     174 """
#     175 self._validate_params()
# --> 176 return self._fit(X)
#
# File ~\OneDrive\Skrivbord\Big Data\venvBigData\lib\site-packages\sklearn\neighbors\_base.py:542, in NeighborsBase._fit(self, X, y)
#     539     return self
#     541 if self.metric == "precomputed":
# --> 542     X = _check_precomputed(X)
#     543     # Precomputed matrix X must be squared
#     544     if X.shape[0] != X.shape[1]:
#
# File ~\OneDrive\Skrivbord\Big Data\venvBigData\lib\site-packages\sklearn\neighbors\_base.py:182, in _check_precomputed(X)
#     180 if not issparse(X):
#     181     X = check_array(X)
# --> 182     check_non_negative(X, whom="precomputed distance matrix.")
#     183     return X
#     184 else:
#
# File ~\OneDrive\Skrivbord\Big Data\venvBigData\lib\site-packages\sklearn\utils\validation.py:1418, in check_non_negative(X, whom)
#    1415     X_min = xp.min(X)
#    1417 if X_min < 0:
# -> 1418     raise ValueError("Negative values in data passed to %s" % whom)
#
# ValueError: Negative values in data passed to precomputed distance matrix.

# %% [markdown]
# ## Step 1
#
# ### Dimension and feature selection techniques suited for unsupervised clustering tasks
#
# 1. Principal Component Analysis (PCA)
# 2. Independent Component Analysis (ICA)
# 3. Random Projections
# 4. Feature Selection based on Clustering Quality
# 5. Recursive Feature Elimination (RFE)
#
# Principal Component Analysis (PCA): PCA is a technique that reduces the dimensionality of the data by identifying the most important features that capture the most variance in the data. PCA is a powerful technique for feature selection, as it can often reduce the number of features required for clustering while still retaining the important information.
#
# Independent Component Analysis (ICA): ICA is a technique that separates the data into independent sources based on statistical properties. ICA can be used for feature selection by identifying the features that have the most independent information, which can help to remove redundant or noisy features.
#
# Random Projections: Random projections is a technique that can be used to reduce the dimensionality of the data by projecting the data onto a lower-dimensional subspace. Random projections can be used for feature selection by identifying the most important dimensions that capture the most variance in the data.
#
# Feature Selection based on Clustering Quality: This approach selects the features that produce the best clustering results. This method works by selecting a subset of features and evaluating the clustering performance with different clustering algorithms, and selecting the subset of features that results in the best clustering performance.
#
# Recursive Feature Elimination (RFE): RFE is a feature selection method that selects features by recursively considering smaller and smaller subsets of features. RFE works by training a model on the full set of features, ranking the importance of the features, and then eliminating the least important feature. This process is repeated until a predetermined number of features is reached.

# %% [markdown]
# ## PCA

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


data_pp = StandardScaler().fit_transform(data)
pca = PCA(svd_solver="auto").fit(data_pp)
# The PCA object offers convenient ways of accessing the
# principal directions and explained variance
pca.components_;
pca.explained_variance_;

# To get the principal components, the `transform` method of the
# PCA object can be used
principal_components_pca = pca.transform(data_pp)

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(6, 4))
ax = fig.gca()

ax.plot(np.arange(1, len(pca.components_) + 1), pca.explained_variance_, 'ok', markersize=2)
ax.axvline(10, linestyle="dashed", color="red", linewidth=1)

ax.set_xlabel("Principal Component")
ax.set_ylabel("Explained Variance");

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

def pca(data, n_components):
    
    # Scale the data
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(data)
    
    # Fit PCA to the scaled data
    pca = PCA(n_components=n_components)
    pca.fit(scaled_data)
    
    # Transform the data using the fitted PCA model
    principal_components = pca.transform(scaled_data)
    
    # Return the principal components and explained variance ratio
    return principal_components

# %% [markdown]
# ### Random projection

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.random_projection import GaussianRandomProjection

rp = GaussianRandomProjection(n_components=82).fit(data)

# Compute the explained variance ratio for each component
explained_variances = np.abs(rp.components_).var(axis=1) / np.abs(rp.components_).var().sum()

# Sort the components based on their explained variance
sorted_indices = np.argsort(explained_variances)[::-1]
explained_variances_sorted = explained_variances[sorted_indices]# Compute the explained variance ratio for each component
explained_variances = np.abs(rp.components_).var(axis=1) / np.abs(rp.components_).var().sum()

# Sort the components based on their explained variance
sorted_indices = np.argsort(explained_variances)[::-1]
explained_variances_sorted = explained_variances[sorted_indices]

# Plot the scree plot
plt.plot(np.arange(1, len(explained_variances) + 1), explained_variances_sorted, 'ok',markersize=2)
plt.axhline(1, linestyle="dashed", color="red", linewidth=1)
plt.xlabel('Component number')
plt.ylabel('Explained variance')
plt.show()

n_components = np.sum(explained_variances_sorted > 1)
print(f'Number of components = {n_components}')
# Out:
# Number of components = 42

# %%
def random_projection(data, nr_components):
    scaled_data = StandardScaler().fit_transform(data)
    return GaussianRandomProjection(n_components=nr_components).fit_transform(scaled_data)

# %% [markdown]
# ## Clustering methods

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import davies_bouldin_score
from sklearn.cluster import SpectralClustering
from sklearn.mixture import GaussianMixture
from sklearn.cluster import AgglomerativeClustering
from scipy.spatial.distance import pdist, squareform

def consensus_index(matrices):
    n = len(matrices)
    total_agreements = 0
    total_pairs = 0

    for i in range(n):
        for j in range(i+1, n):
            total_agreements += np.sum(matrices[i] == matrices[j])
            total_pairs += matrices[i].size

    return total_agreements / total_pairs


def kmeans_clustering_score(reduced_data, nr_clusters, score):
    kmeans = KMeans(init="k-means++", n_clusters=nr_clusters, n_init='auto').fit(reduced_data)
    pred = kmeans.labels_
    if score == 'silh':
        score = silhouette_score(reduced_data, pred, metric='euclidean')
    elif score == 'calinski':
        score = calinski_harabasz_score(reduced_data, pred)
    elif score == 'davies':
        score = davies_bouldin_score(reduced_data, pred)
        
    co_association_matrix = 1 - squareform(pdist(pred[:, np.newaxis], metric='hamming'))
    return score, pred, co_association_matrix

def spectral_clustering_score(reduced_data, nr_clusters, score):
    sc = SpectralClustering(n_clusters=nr_clusters, eigen_solver='lobpcg', n_init=10, gamma=1.0, affinity='precomputed_nearest_neighbors',
                        n_neighbors=10, assign_labels='kmeans')
    pred = sc.fit_predict(reduced_data)
    if score == 'silh':
        score = silhouette_score(reduced_data, pred, metric='euclidean')
    elif score == 'calinski':
        score = calinski_harabasz_score(reduced_data, pred)
    elif score == 'davies':
        score = davies_bouldin_score(reduced_data, pred)
        
    co_association_matrix = 1 - squareform(pdist(pred[:, np.newaxis], metric='hamming'))
    return score, pred, co_association_matrix

def gmm_clustering_score(reduced_data, nr_clusters, score):
    gmm = GaussianMixture(n_components=nr_clusters, covariance_type='spherical')
    pred = gmm.fit_predict(reduced_data)
    if score == 'silh':
        score = silhouette_score(reduced_data, pred, metric='euclidean')
    elif score == 'calinski':
        score = calinski_harabasz_score(reduced_data, pred)
    elif score == 'davies':
        score = davies_bouldin_score(reduced_data, pred)
        
    co_association_matrix = 1 - squareform(pdist(pred[:, np.newaxis], metric='hamming'))
    return score, pred, co_association_matrix

def agglomerative_clustering_score(reduced_data, nr_clusters, score):
    agglomerative_clustering = AgglomerativeClustering(n_clusters=nr_clusters, metric='euclidean', linkage='ward')
    pred = agglomerative_clustering.fit_predict(reduced_data)
    if score == 'silh':
        score = silhouette_score(reduced_data, pred, metric='euclidean')
    elif score == 'calinski':
        score = calinski_harabasz_score(reduced_data, pred)
    elif score == 'davies':
        score = davies_bouldin_score(reduced_data, pred)
            
    co_association_matrix = 1 - squareform(pdist(pred[:, np.newaxis], metric='hamming'))
    return score, pred, co_association_matrix

# %%
from tqdm import trange
from tqdm import tqdm
import numpy as np

def evaluate(nr_PC, nr_clusters_list, data, method, iterations, metric):
    reduced_data = pca(data, nr_PC)
    cluster_dict = {}
    ci_dict = {}
    for c in nr_clusters_list:
        score_list = []
        co_association_matrices = []
        for i in tqdm(range(iterations), desc=f"Number of clusters {c}", position=0):
            if method == 'kmeans':
                score, pred_label, co_mat = kmeans_clustering_score(reduced_data, c, metric)
                
            elif method == 'spectral':
                score, pred_label, co_mat = spectral_clustering_score(reduced_data, c, metric)
            
            elif method == 'gmm':
                score, pred_label, co_mat = gmm_clustering_score(reduced_data, c, metric)
                
            elif method == 'agglo':
                score, pred_label, co_mat = agglomerative_clustering_score(reduced_data, c, metric)
            
            co_association_matrices.append(co_mat)
            score_list.append(score)
        
        ci_dict[c] = consensus_index(co_association_matrices)
        cluster_dict[c] = np.mean(score_list)
    return cluster_dict, pred_label, ci_dict

# %% [markdown]
# ***Taking out scores for the different metrics that depends on the nr of clusters***

# %%
import pandas as pd
import matplotlib.pyplot as plt
clfs_name = ['2', '3', '4', '5']
def barplot(score_values, score_names, Title):
    df = pd.DataFrame(score_values, index=score_names, columns=clfs_name)
    ax = df.plot.bar(rot=0, figsize=(10,6))
    
    
    # Add score names below the bars
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=len(clfs_name), title='Number of clusters')
    ax.set_ylabel('Value')
    ax.set_xticklabels(score_names)
    ax.set_title(Title)
    
    # Add exact values above the bars
    for i in ax.containers:
        ax.bar_label(i, label_type='edge', fmt='%.2f', fontsize=6)
    
    plt.show()

# %%
# Function arguments
nr_clusters_list = [2, 3, 4, 5]
nr_PC = 10
iterations = 500

silhouette_scores = []
calinski_scores = []
davies_bouldin_scores = []
ci_scores = []

methods = ['kmeans', 'spectral', 'gmm', 'agglo']
for method in methods:
    print(method)
    silhouette_score_dict, pred_label, ci = evaluate(nr_PC, nr_clusters_list, data, method, iterations, 'silh')
    print(f'Silhoutte scores for {method}:\n {silhouette_score_dict}')
    
    silhouette_scores.append(silhouette_score_dict.values())

    calinski_score_dict, pred_label, _ = evaluate(nr_PC, nr_clusters_list, data, method, iterations, 'calinski')
    print(f'Calinski-Harabasz scores for {method}:\n {calinski_score_dict}')
    
    calinski_scores.append(calinski_score_dict.values())

    davies_bouldin_dict, pred_label, _ = evaluate(nr_PC, nr_clusters_list, data, method, iterations, 'davies')
    print(f'Davies-Bouldin scores for {method}:\n {davies_bouldin_dict}')
    
    davies_bouldin_scores.append(davies_bouldin_dict.values())
    
    
    ci_scores.append(ci.values())
# Out:
# kmeans
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 500/500 [00:05<00:00, 93.04it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 500/500 [00:05<00:00, 88.13it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 500/500 [00:05<00:00, 90.33it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 500/500 [00:05<00:00, 83.63it/s]
# Silhoutte scores for kmeans:
#  {2: 0.1680175555602277, 3: 0.16397297779086994, 4: 0.17939147034472072, 5: 0.18984924869834907}
# Number of clusters 2: 100%|█████████████████████████████████████████████████████████| 500/500 [00:04<00:00, 111.01it/s]
# Number of clusters 3: 100%|█████████████████████████████████████████████████████████| 500/500 [00:04<00:00, 101.10it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 500/500 [00:05<00:00, 98.14it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 500/500 [00:05<00:00, 90.79it/s]
# Calinski-Harabasz scores for kmeans:
#  {2: 17.242814014791445, 3: 15.442631359638026, 4: 14.420513744758871, 5: 13.816665527927722}
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 500/500 [00:05<00:00, 93.16it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 500/500 [00:05<00:00, 88.54it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 500/500 [00:06<00:00, 82.81it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 500/500 [00:06<00:00, 72.13it/s]
# Davies-Bouldin scores for kmeans:
#  {2: 2.0079367675743365, 3: 1.8403819232311611, 4: 1.7608254022253509, 5: 1.6661392006668634}
# spectral
# Number of clusters 2:   0%|                                                                    | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 14
#      12 for method in methods:
#      13     print(method)
# ---> 14     silhouette_score_dict, pred_label, ci = evaluate(nr_PC, nr_clusters_list, data, method, iterations, 'silh')
#      15     print(f'Silhoutte scores for {method}:\n {silhouette_score_dict}')
#      17     silhouette_scores.append(silhouette_score_dict.values())
#
# Cell In[8], line 17, in evaluate(nr_PC, nr_clusters_list, data, method, iterations, metric)
#      14     score, pred_label, co_mat = kmeans_clustering_score(reduced_data, c, metric)
#      16 elif method == 'spectral':
# ---> 17     score, pred_label, co_mat = spectral_clustering_score(reduced_data, c, metric)
#      19 elif method == 'gmm':
#      20     score, pred_label, co_mat = gmm_clustering_score(reduced_data, c, metric)
#
# Cell In[7], line 40, in spectral_clustering_score(reduced_data, nr_clusters, score)
#      37 def spectral_clustering_score(reduced_data, nr_clusters, score):
#      38     sc = SpectralClustering(n_clusters=nr_clusters, eigen_solver='lobpcg', n_init=10, gamma=1.0, affinity='precomputed_nearest_neighbors',
#      39                         n_neighbors=10, assign_labels='kmeans')
# ---> 40     pred = sc.fit_predict(reduced_data)
#      41     if score == 'silh':
#      42         score = silhouette_score(reduced_data, pred, metric='euclidean')
#
# File ~\OneDrive\Skrivbord\Big Data\venvBigData\lib\site-packages\sklearn\cluster\_spectral.py:785, in SpectralClustering.fit_predict(self, X, y)
#     763 def fit_predict(self, X, y=None):
#     764     """Perform spectral clustering on `X` and return cluster labels.
#     765
#     766     Parameters
#    (...)
#     783         Cluster labels.
#     784     """
# --> 785     return super().fit_predict(X, y)
#
# File ~\OneDrive\Skrivbord\Big Data\venvBigData\lib\site-packages\sklearn\base.py:753, in ClusterMixin.fit_predict(self, X, y)
#     735 """
#     736 Perform clustering on `X` and returns cluster labels.
#     737
#    (...)
#     749     Cluster labels.
#     750 """
#     751 # non-optimized default implementation; override when a better
#     752 # method is possible for a given clustering algorithm
# --> 753 self.fit(X)
#     754 return self.labels_
#
# File ~\OneDrive\Skrivbord\Big Data\venvBigData\lib\site-packages\sklearn\cluster\_spectral.py:732, in SpectralClustering.fit(self, X, y)
#     728     self.affinity_matrix_ = 0.5 * (connectivity + connectivity.T)
#     729 elif self.affinity == "precomputed_nearest_neighbors":
#     730     estimator = NearestNeighbors(
#     731         n_neighbors=self.n_neighbors, n_jobs=self.n_jobs, metric="precomputed"
# --> 732     ).fit(X)
#     733     connectivity = estimator.kneighbors_graph(X=X, mode="connectivity")
#     734     self.affinity_matrix_ = 0.5 * (connectivity + connectivity.T)
#
# File ~\OneDrive\Skrivbord\Big Data\venvBigData\lib\site-packages\sklearn\neighbors\_unsupervised.py:176, in NearestNeighbors.fit(self, X, y)
#     159 """Fit the nearest neighbors estimator from the training dataset.
#     160
#     161 Parameters
#    (...)
#     173     The fitted nearest neighbors estimator.
#     174 """
#     175 self._validate_params()
# --> 176 return self._fit(X)
#
# File ~\OneDrive\Skrivbord\Big Data\venvBigData\lib\site-packages\sklearn\neighbors\_base.py:542, in NeighborsBase._fit(self, X, y)
#     539     return self
#     541 if self.metric == "precomputed":
# --> 542     X = _check_precomputed(X)
#     543     # Precomputed matrix X must be squared
#     544     if X.shape[0] != X.shape[1]:
#
# File ~\OneDrive\Skrivbord\Big Data\venvBigData\lib\site-packages\sklearn\neighbors\_base.py:182, in _check_precomputed(X)
#     180 if not issparse(X):
#     181     X = check_array(X)
# --> 182     check_non_negative(X, whom="precomputed distance matrix.")
#     183     return X
#     184 else:
#
# File ~\OneDrive\Skrivbord\Big Data\venvBigData\lib\site-packages\sklearn\utils\validation.py:1418, in check_non_negative(X, whom)
#    1415     X_min = xp.min(X)
#    1417 if X_min < 0:
# -> 1418     raise ValueError("Negative values in data passed to %s" % whom)
#
# ValueError: Negative values in data passed to precomputed distance matrix.

# %%
score_list = [silhouette_scores, calinski_scores, davies_bouldin_scores, ci_scores]
metric_names = ['Silhouette score', 'Calinski-Harabasz score', 'Davies-Bouldin score', 'Consensus index']
for i, score in enumerate(score_list):
    clf_names = ['Kmeans', 'Spectral', 'GMM', 'Agglomerative']
    barplot(score, clf_names, metric_names[i])

# %% [markdown]
# ***Investigate how sensitive the results are to the nr of principal components***

# %%
from collections import Counter
from collections import defaultdict




def pc_check(method, score_name, nr_clusters_list):
    my_dict = defaultdict(list)
    nr_PC = [5, 10, 20, 30, 82]
    iterations = 100

    for pc in nr_PC:
        score_dict, pred_label = evaluate(pc, nr_clusters_list, data, method, iterations, score_name)
        best_score = 0
        for key, val in score_dict.items():
            my_dict[key].append(val)
            
    return my_dict

# %%
# creating a function that spits out all the variances for each clustering method in a dict for a specified score metric
nr_clusters_list = [2, 3, 4, 5]
def cv_score(cluster_method, score_metric:str, clusters:list):
    cv = lambda x: np.std(x, ddof=1) / np.mean(x) * 100
    cv_scores = []
    my_dict = pc_check(cluster_method, score_metric, clusters)
    for key, values in my_dict.items():
        cv_scores.append(cv(values))
    return cv_scores

silhouette_cvscores = []
calinski_cvscores = []
davies_cvscores = []

methods = ['kmeans', 'spectral', 'gmm', 'agglo']
for method in methods:

    silhouette_cvscore = cv_score(method, 'silh', nr_clusters_list)
    silhouette_cvscores.append(silhouette_cvscore)
    
    calinski_cvscore = cv_score(method, 'calinski', nr_clusters_list)
    calinski_cvscores.append(calinski_cvscore)
    
    davies_cvscore = cv_score(method, 'davies', nr_clusters_list)
    davies_cvscores.append(davies_cvscore)
# Out:
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 66.72it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.02it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 56.11it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 54.27it/s]
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.44it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.27it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 56.18it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 52.87it/s]
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 61.69it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 57.98it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 55.78it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 53.09it/s]
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.98it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 57.74it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 57.12it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 54.45it/s]
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.62it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 56.58it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 54.29it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 51.98it/s]
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 69.74it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 74.50it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 63.74it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.11it/s]
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 69.74it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 67.67it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 62.04it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.84it/s]
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 69.73it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 64.30it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 63.77it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 57.72it/s]
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 69.09it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 64.77it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 62.42it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 57.12it/s]
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 67.17it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 66.77it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.35it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.46it/s]
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.21it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 56.07it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 51.91it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 50.46it/s]
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 63.92it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 61.08it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 51.88it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 100/100 [00:02<00:00, 48.62it/s]
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.33it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 55.44it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 51.63it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 100/100 [00:02<00:00, 47.85it/s]
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.90it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 56.88it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 51.27it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 100/100 [00:02<00:00, 49.00it/s]
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 58.83it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 59.45it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 67.08it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 100/100 [00:02<00:00, 48.41it/s]
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 100/100 [00:03<00:00, 26.20it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 100/100 [00:06<00:00, 14.45it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 100/100 [00:04<00:00, 20.12it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 100/100 [00:04<00:00, 20.91it/s]
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 100/100 [00:03<00:00, 29.56it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 100/100 [00:05<00:00, 18.38it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 100/100 [00:04<00:00, 20.04it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 100/100 [00:05<00:00, 17.72it/s]
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 100/100 [00:04<00:00, 21.23it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 100/100 [00:06<00:00, 16.37it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 100/100 [00:06<00:00, 15.90it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 14.26it/s]
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 100/100 [00:04<00:00, 21.15it/s]
# Number of clusters 3: 100%|██████████████████████████████████████████████████████████| 100/100 [00:06<00:00, 16.62it/s]
# Number of clusters 4: 100%|██████████████████████████████████████████████████████████| 100/100 [00:06<00:00, 16.41it/s]
# Number of clusters 5: 100%|██████████████████████████████████████████████████████████| 100/100 [00:07<00:00, 14.27it/s]
# Number of clusters 2:   0%|                                                                    | 0/100 [00:00<?, ?it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:   3%|█▊                                                          | 3/100 [00:00<00:04, 22.22it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:   6%|███▌                                                        | 6/100 [00:00<00:04, 22.08it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:   9%|█████▍                                                      | 9/100 [00:00<00:04, 21.44it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  12%|███████                                                    | 12/100 [00:00<00:04, 21.12it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  15%|████████▊                                                  | 15/100 [00:00<00:04, 20.89it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  18%|██████████▌                                                | 18/100 [00:00<00:03, 20.89it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  21%|████████████▍                                              | 21/100 [00:00<00:03, 21.06it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  24%|██████████████▏                                            | 24/100 [00:01<00:03, 20.97it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  27%|███████████████▉                                           | 27/100 [00:01<00:03, 20.98it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  30%|█████████████████▋                                         | 30/100 [00:01<00:03, 20.97it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  33%|███████████████████▍                                       | 33/100 [00:01<00:03, 21.01it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  36%|█████████████████████▏                                     | 36/100 [00:01<00:03, 21.30it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  39%|███████████████████████                                    | 39/100 [00:01<00:02, 20.97it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  42%|████████████████████████▊                                  | 42/100 [00:01<00:02, 22.27it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  45%|██████████████████████████▌                                | 45/100 [00:02<00:02, 22.61it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  48%|████████████████████████████▎                              | 48/100 [00:02<00:02, 23.62it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  51%|██████████████████████████████                             | 51/100 [00:02<00:02, 24.49it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  54%|███████████████████████████████▊                           | 54/100 [00:02<00:01, 24.12it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  57%|█████████████████████████████████▋                         | 57/100 [00:02<00:01, 24.21it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  60%|███████████████████████████████████▍                       | 60/100 [00:02<00:01, 22.88it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  63%|█████████████████████████████████████▏                     | 63/100 [00:02<00:01, 22.27it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  66%|██████████████████████████████████████▉                    | 66/100 [00:03<00:01, 21.99it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  69%|████████████████████████████████████████▋                  | 69/100 [00:03<00:01, 21.62it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  72%|██████████████████████████████████████████▍                | 72/100 [00:03<00:01, 21.08it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  75%|████████████████████████████████████████████▎              | 75/100 [00:03<00:01, 21.64it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  78%|██████████████████████████████████████████████             | 78/100 [00:03<00:01, 21.50it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  81%|███████████████████████████████████████████████▊           | 81/100 [00:03<00:00, 21.75it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  84%|█████████████████████████████████████████████████▌         | 84/100 [00:03<00:00, 23.22it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  87%|███████████████████████████████████████████████████▎       | 87/100 [00:03<00:00, 23.84it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  90%|█████████████████████████████████████████████████████      | 90/100 [00:04<00:00, 24.19it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  93%|██████████████████████████████████████████████████████▊    | 93/100 [00:04<00:00, 24.45it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  96%|████████████████████████████████████████████████████████▋  | 96/100 [00:04<00:00, 24.05it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2:  99%|██████████████████████████████████████████████████████████▍| 99/100 [00:04<00:00, 24.79it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 2: 100%|██████████████████████████████████████████████████████████| 100/100 [00:04<00:00, 22.40it/s]
# Number of clusters 3:   0%|                                                                    | 0/100 [00:00<?, ?it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 3:   2%|█▏                                                          | 2/100 [00:00<00:05, 18.65it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# Number of clusters 3:   4%|██▍                                                         | 4/100 [00:00<00:05, 18.31it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_spectral.py:717: UserWarning: The spectral clustering API has changed. ``fit``now constructs an affinity matrix from data. To use a custom affinity matrix, set ``affinity=precomputed``.
#   warnings.warn(
# ...
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Number of clusters 5:  60%|██████████████████████████████████▊                       | 60/100 [00:00<00:00, 159.23it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Number of clusters 5:  77%|████████████████████████████████████████████▋             | 77/100 [00:00<00:00, 148.07it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Number of clusters 5:  93%|█████████████████████████████████████████████████████▉    | 93/100 [00:00<00:00, 143.00it/s]C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# C:\Users\axelq\OneDrive\Skrivbord\MpCas\Statistical learning for big data\bigdatavenv1\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Number of clusters 5: 100%|█████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 152.10it/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
clfs_name = [str(i) for i in nr_clusters_list]
def barplot(score_values, score_names, Title):
    df = pd.DataFrame(score_values, index=score_names, columns=clfs_name)
    ax = df.plot.bar(rot=0, figsize=(10,6))
    
    
    # Add score names below the bars
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1), ncol=len(clfs_name), title='Number of clusters')
    ax.set_ylabel('Coefficient Variation')
    ax.set_xticklabels(score_names)
    ax.set_title(Title)
    
    # Add exact values above the bars
    for i in ax.containers:
        ax.bar_label(i, label_type='edge', fmt='%.2f', fontsize=6)
    
    plt.show()
    
    
score_list = [silhouette_cvscores, calinski_cvscores, davies_cvscores]
metric_names = ['Silhouette score', 'Calinski-Harabasz score', 'Davies-Bouldin score']
for i, score in enumerate(score_list):
    clf_names = ['Kmeans', 'Spectral', 'GMM', 'Agglomerative']
    barplot(score, clf_names, metric_names[i])
